# %% [markdown]
# **The main steps for running a trace fear conditioning experiment are:**
# 0: Handle animals
# 1: Set up hardware
# 2: Set up software
# 3: Run experiment
# 4: Clean up + Organize/Backup data
#
# This document deals with steps 1 and 2.

# %% [markdown]
# # Setup boxes
#
# First you need to make sure all the boxes are in the correct places and have microphones attached.

# %%
os.getcwd()
# Out:
# 'C:\\Users\\nkinsky\\Documents\\ephys\\behavior\\Python\\Trace_FC_documentation'

# %% [markdown]
# from IPython import display

# %% [markdown]
# ![test](C:\\Users\\nkinsky\\Desktop\\trace_fc_instructions\\General_setup.jpg)

# %%
display.Image(r'C:\Users\nkinsky\Desktop\trace_fc_instructions\General_setup.jpg')
